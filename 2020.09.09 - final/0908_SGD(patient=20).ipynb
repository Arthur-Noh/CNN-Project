# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
TRAIN_DIR = "C:/Users/USER/Downloads/0810_CNN/Train"
TEST_DIR = "C:/Users/USER/Downloads/0810_CNN/Test"

CATEGORIES = ['blackice','road','snow','wet']

for category in CATEGORIES:
    path=os.path.join(TRAIN_DIR,category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE) #GRAYSCALE=흑백, COLOR_BGR2RGB=컬러
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break
    
for category in CATEGORIES:
    path=os.path.join(TEST_DIR,category)
    for img in os.listdir(path):  
        img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE) #뒤에 GRAYSCALE은 흑백으로 변환한 것을 의미함
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
    break

# %%
IMG_SIZE=150

new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
plt.imshow(new_array, cmap='gray')
plt.show()

# %%
training_data = []
testing_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(TRAIN_DIR, category)
        class_num = CATEGORIES.index(category)
        
        for image in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, image),
                                    cv2.IMREAD_GRAYSCALE)
                fix_img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
                training_data.append([fix_img_arr, class_num])
            except Exception as e:
                pass
            
def create_testing_data():
    for category in CATEGORIES:
        path = os.path.join(TEST_DIR, category)
        class_num = CATEGORIES.index(category)
        
        for image in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, image),
                                    cv2.IMREAD_GRAYSCALE)
                fix_img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
                testing_data.append([fix_img_arr, class_num])
            except Exception as e:
                pass
            
create_training_data()
create_testing_data()

# %%
print(len(training_data))
print(len(testing_data))
# Out:
# 40000
# 4000

# %%
import random

random.shuffle(training_data)
random.shuffle(testing_data)

train_X=[]
test_X=[]
train_y=[]
test_y=[]

for features, label in training_data:
    train_X.append(features)
    train_y.append(label)
    
for features, label in testing_data:
    test_X.append(features)
    test_y.append(label)
    
train_X=np.array(train_X).reshape(-1,IMG_SIZE,IMG_SIZE,1)
test_X=np.array(test_X).reshape(-1,IMG_SIZE,IMG_SIZE,1)
train_y=np.array(train_y)
test_y=np.array(test_y)

train_X=train_X/255
test_X=test_X/255

# %%
print(train_X.shape, train_y.shape)
print(test_X.shape, test_y.shape)
# Out:
# (40000, 150, 150, 1) (40000,)
# (4000, 150, 150, 1) (4000,)

# %%
from tensorflow import keras
model=tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(150,150,1), kernel_size=(3,3), filters=32, padding='same',activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Dropout(rate=0.2),
    
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Dropout(rate=0.2),
    
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Dropout(rate=0.2),
    
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=512, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(strides=(2,2)),
    tf.keras.layers.Dropout(rate=0.2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=1024, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=4, activation='softmax')
])
# sparse 빼도됨
model.compile(optimizer=tf.keras.optimizers.SGD(),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 37, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 512)         1180160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 6,683,140
# Trainable params: 6,683,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
gpus=tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
     # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu,True)
        logical_gpus=tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus),"Physical GPUs,",len(logical_gpus),"Logical GPUs")
    except RuntimeError as e:
        #Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
from keras.callbacks import EarlyStopping
early_stopping=EarlyStopping(monitor='val_loss', mode='min', min_delta=1e-3, patience=20, verbose=1)
history=model.fit(train_X,train_y,epochs=200,validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/200
#    2/1000 [..............................] - ETA: 56s - loss: 1.3822 - accuracy: 0.3906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0060s vs `on_train_batch_end` time: 0.1037s). Check your callbacks.
# 1000/1000 [==============================] - ETA: 0s - loss: 1.1983 - accuracy: 0.3808WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.
200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.1305 - val_accuracy: 0.9581
# Epoch 72/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0491 - val_accuracy: 0.9856
# Epoch 73/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0467 - val_accuracy: 0.9849
# Epoch 74/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.1277 - val_accuracy: 0.9619
# Epoch 75/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.1287 - val_accuracy: 0.9634
# Epoch 76/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0406 - val_accuracy: 0.9868
# Epoch 77/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.0470 - val_accuracy: 0.9856
# Epoch 78/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.0698 - val_accuracy: 0.9791
# Epoch 79/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0425 - val_accuracy: 0.9860
# Epoch 80/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.0402 - val_accuracy: 0.9876
# Epoch 81/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.0420 - val_accuracy: 0.9876
# Epoch 82/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0539 - val_accuracy: 0.9844
# Epoch 83/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.0640 - val_accuracy: 0.9810
# Epoch 84/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0572 - val_accuracy: 0.9839
# Epoch 85/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0513 - val_accuracy: 0.9837
# Epoch 86/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0175 - accuracy: 0.9945 - val_loss: 0.0702 - val_accuracy: 0.9772
# Epoch 87/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0468 - val_accuracy: 0.9845
# Epoch 88/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0429 - val_accuracy: 0.9874
# Epoch 89/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0537 - val_accuracy: 0.9841
# Epoch 90/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0575 - val_accuracy: 0.9837
# Epoch 91/200
# 1000/1000 [==============================] - 117s 117ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0586 - val_accuracy: 0.9831
# Epoch 92/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0533 - val_accuracy: 0.9844
# Epoch 93/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0383 - val_accuracy: 0.9894
# Epoch 94/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0409 - val_accuracy: 0.9879
# Epoch 95/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0791 - val_accuracy: 0.9751
# Epoch 96/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 0.0522 - val_accuracy: 0.9847
# Epoch 97/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0456 - val_accuracy: 0.9865
# Epoch 98/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0558 - val_accuracy: 0.9831
# Epoch 99/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0492 - val_accuracy: 0.9868
# Epoch 100/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.0414 - val_accuracy: 0.9872
# Epoch 101/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.1322 - val_accuracy: 0.9650
# Epoch 102/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0682 - val_accuracy: 0.9808
# Epoch 103/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.0394 - val_accuracy: 0.9886
# Epoch 104/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0599 - val_accuracy: 0.9827
# Epoch 105/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0379 - val_accuracy: 0.9890
# Epoch 106/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0756 - val_accuracy: 0.9770
# Epoch 107/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1047 - val_accuracy: 0.9715
# Epoch 108/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0421 - val_accuracy: 0.9889
# Epoch 109/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0351 - val_accuracy: 0.9902
# Epoch 110/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0779 - val_accuracy: 0.9806
# Epoch 111/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0542 - val_accuracy: 0.9864
# Epoch 112/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0582 - val_accuracy: 0.9831
# Epoch 113/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0577 - val_accuracy: 0.9840
# Epoch 114/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0866 - val_accuracy: 0.9741
# Epoch 115/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0334 - val_accuracy: 0.9902
# Epoch 116/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0437 - val_accuracy: 0.9879
# Epoch 117/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0488 - val_accuracy: 0.9872
# Epoch 118/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0524 - val_accuracy: 0.9850
# Epoch 119/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0433 - val_accuracy: 0.9870
# Epoch 120/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.0407 - val_accuracy: 0.9877
# Epoch 121/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.0480 - val_accuracy: 0.9856
# Epoch 122/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0391 - val_accuracy: 0.9886
# Epoch 123/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0426 - val_accuracy: 0.9885
# Epoch 124/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0609 - val_accuracy: 0.9825
# Epoch 125/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0401 - val_accuracy: 0.9895
# Epoch 126/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 0.0334 - val_accuracy: 0.9895
# Epoch 127/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0375 - accuracy: 0.9922 - val_loss: 0.0418 - val_accuracy: 0.9871
# Epoch 128/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0048 - accuracy: 0.9989 - val_loss: 0.0519 - val_accuracy: 0.9855
# Epoch 129/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0381 - val_accuracy: 0.9891
# Epoch 130/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0366 - val_accuracy: 0.9890
# Epoch 131/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0318 - val_accuracy: 0.9899
# Epoch 132/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0321 - val_accuracy: 0.9906
# Epoch 133/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0879 - val_accuracy: 0.9750
# Epoch 134/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0428 - val_accuracy: 0.9889
# Epoch 135/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0383 - val_accuracy: 0.9891
# Epoch 136/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.0535 - val_accuracy: 0.9852
# Epoch 137/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0846 - val_accuracy: 0.9778
# Epoch 138/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0412 - val_accuracy: 0.9893
# Epoch 139/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0409 - val_accuracy: 0.9895
# Epoch 140/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0340 - val_accuracy: 0.9906
# Epoch 141/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0541 - val_accuracy: 0.9859
# Epoch 142/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0464 - val_accuracy: 0.9866
# Epoch 143/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0444 - val_accuracy: 0.9887
# Epoch 144/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0612 - val_accuracy: 0.9814
# Epoch 145/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0407 - val_accuracy: 0.9890
# Epoch 146/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0408 - val_accuracy: 0.9876
# Epoch 147/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0607 - val_accuracy: 0.9834
# Epoch 148/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0375 - val_accuracy: 0.9894
# Epoch 149/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0622 - val_accuracy: 0.9850
# Epoch 150/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0353 - val_accuracy: 0.9909
# Epoch 151/200
# 1000/1000 [==============================] - 118s 118ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0380 - val_accuracy: 0.9899
# Epoch 00151: early stopping

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'],'b-',label='loss')
plt.plot(history.history['val_loss'],'r--',label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'],'g-',label='accuracy')
plt.plot(history.history['val_accuracy'],'k--',label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.3,1)
plt.legend()

plt.show()

# %%
model.evaluate(train_X,train_y,verbose=0)
# Out:
# [0.007701402064412832, 0.9979749917984009]

# %%
model.evaluate(test_X,test_y,verbose=0)
# Out:
# [0.09677678346633911, 0.9817500114440918]

# %%
import pandas as pd
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions=model.predict(test_X)
print(predictions)
# Out:
# [[9.9803776e-01 1.1108252e-07 1.9582727e-03 3.8264598e-06]
#  [9.9114639e-10 9.9999976e-01 7.9824057e-11 2.4794369e-07]
#  [2.3901180e-13 3.7155461e-17 1.0000000e+00 7.4660560e-14]
#  ...
#  [4.5739506e-09 8.2675342e-09 3.5074781e-09 1.0000000e+00]
#  [8.2796573e-12 1.0000000e+00 1.7855223e-13 9.9870361e-09]
#  [1.2552960e-07 3.8599333e-09 9.9999988e-01 1.3241982e-08]]

# %%
print(confusion_matrix(test_y,np.argmax(predictions,axis=1)))
print(classification_report(test_y,np.argmax(predictions,axis=1)))
# Out:
# [[961   9  24   6]
#  [  0 996   0   4]
#  [ 15   2 981   2]
#  [  1   7   3 989]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1000
#            1       0.98      1.00      0.99      1000
#            2       0.97      0.98      0.98      1000
#            3       0.99      0.99      0.99      1000
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000

# %%
predictions2=model.predict(train_X)
print(confusion_matrix(train_y,np.argmax(predictions2,axis=1)))
print(classification_report(train_y,np.argmax(predictions2,axis=1)))
# Out:
# [[9952    6   35    7]
#  [   0 9997    0    3]
#  [  11    1 9987    1]
#  [   1   13    3 9983]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10000
#            1       1.00      1.00      1.00     10000
#            2       1.00      1.00      1.00     10000
#            3       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     40000
#    macro avg       1.00      1.00      1.00     40000
# weighted avg       1.00      1.00      1.00     40000

# %%
confusion_mtx = confusion_matrix(train_y,np.argmax(predictions2,axis=1))
classes = ['blackice', 'road', 'snow', 'wet']

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylabel('True label')
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i,j], horizontalalignment="center", color='white' if cm[i, j] > thresh else "black") 
    
    plt.tight_layout()

# %%
import itertools

# %%
plot_confusion_matrix(confusion_mtx, classes)
